# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Подготовка-функций-для-дальнейшего-анализа" data-toc-modified-id="Подготовка-функций-для-дальнейшего-анализа-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка функций для дальнейшего анализа</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей---get_profiles()" data-toc-modified-id="Профили-пользователей---get_profiles()-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Профили пользователей - get_profiles()</a></span></li><li><span><a href="#Функция-для-расчёта-удержания-get_retention()" data-toc-modified-id="Функция-для-расчёта-удержания-get_retention()-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Функция для расчёта удержания get_retention()</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-расчета-LTV-и-ROI" data-toc-modified-id="Функция-расчета-LTV-и-ROI-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Функция расчета LTV и ROI</a></span></li><li><span><a href="#Функция-сглаживания-графиков" data-toc-modified-id="Функция-сглаживания-графиков-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Функция сглаживания графиков</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ" data-toc-modified-id="Исследовательский-анализ-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей" data-toc-modified-id="Профили-пользователей-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Профили пользователей</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Распределение-затрат-по-каналам" data-toc-modified-id="Распределение-затрат-по-каналам-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Распределение затрат по каналам</a></span></li><li><span><a href="#Динамика-расходов" data-toc-modified-id="Динамика-расходов-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Динамика расходов</a></span></li><li><span><a href="#Стоимость-привлечения-пользователей" data-toc-modified-id="Стоимость-привлечения-пользователей-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Стоимость привлечения пользователей</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы" data-toc-modified-id="Оценка-окупаемости-рекламы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Оценка окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Общая-окупаемость,-конверсия-и-удержание" data-toc-modified-id="Общая-окупаемость,-конверсия-и-удержание-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Общая окупаемость, конверсия и удержание</a></span></li><li><span><a href="#Анализ-метрик-по-параметрам" data-toc-modified-id="Анализ-метрик-по-параметрам-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Анализ метрик по параметрам</a></span><ul class="toc-item"><li><span><a href="#Удержание" data-toc-modified-id="Удержание-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Удержание</a></span></li><li><span><a href="#Конверсия" data-toc-modified-id="Конверсия-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Конверсия</a></span></li><li><span><a href="#LTV,-ROI" data-toc-modified-id="LTV,-ROI-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>LTV, ROI</a></span></li></ul></li><li><span><a href="#Выводы-и-рекомендации" data-toc-modified-id="Выводы-и-рекомендации-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Выводы и рекомендации</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Описание проекта
# В проекте проведен анализ маркетинговых показателей развлекательного приложения Procrastinate Pro+, убыточного на протяжении последних нескольких месяцев.
# <br>Рассмотрены данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.
#
# <br>В ходе исследования изучено:
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов,
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.
#
# <br>Сделаны выводы о причинах неудачи рекламной кампании и даны рекомендации по их устранению.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %%
try:
    visits, orders, costs = (
    pd.read_csv('https://code.s3.yandex.net/datasets/visits_info_short.csv'),
    pd.read_csc('https://code.s3.yandex.net/datasets/orders_info_short.csv'),
    pd.read_csv('https://code.s3.yandex.net/datasets/costs_info_short.csv')
)
except:
    visits, orders, costs = (
    pd.read_csv('visits_info_short.csv'),
    pd.read_csv('orders_info_short.csv'),
    pd.read_csv('costs_info_short.csv')
)

# %% [markdown]
# ## Предобработка данных
# Начнем с базовой информации о датасете:

# %%
visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# 310 тысяч строк, данные о времени в строковом формате, пропусков нет. Проверим на наличие полных дубликатов:

# %%
visits.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Подробнее рассмотрим значения в столбцах:

# %%
for item in ['Region', 'Device', 'Channel']:
    print('Уникальные значения в столбце:',item, visits[item].unique())
    print('Количество уникальных значений', visits[item].nunique())
# Out:
# Уникальные значения в столбце: Region ['United States' 'UK' 'France' 'Germany']
# Количество уникальных значений 4
# Уникальные значения в столбце: Device ['iPhone' 'Mac' 'Android' 'PC']
# Количество уникальных значений 4
# Уникальные значения в столбце: Channel ['organic' 'TipTop' 'RocketSuperAds' 'YRabbit' 'FaceBoom' 'MediaTornado'
#  'AdNonSense' 'LeapBob' 'WahooNetBanner' 'OppleCreativeMedia'
#  'lambdaMediaAds']
# Количество уникальных значений 11

# %% [markdown]
# В датасете представлены данные о посетителях из четырех регионов, с четырех типов стройств, пришедшие из десяти различных рекламных источников, а также органических посетителей.

# %% [markdown]
# Приведем названия столбцов к общепринятому виду:

# %%
visits.columns = visits.columns.str.lower()
visits = visits.rename(columns={'user id': 'user_id', 'session start' : 'session_start', 'session end' : 'session_end'})

# %% [markdown]
# Изменим формат в столбцах началаи окончания сессии

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %% [markdown]
# Проведем аналогичную предобработку для двух других таблиц:

# %%
#таблица с информацией о покупках
orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
orders.columns = orders.columns.str.lower()
orders = orders.rename(columns={'user id' : 'user_id', 'event dt' : 'event_dt'})
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %%
#таблица с информациях о затратах на рекламу
costs.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
costs.duplicated().sum()
# Out:
# 0

# %%
costs.columns = costs.columns.str.lower()
costs['dt'] = pd.to_datetime(costs['dt'])
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   datetime64[ns]
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 42.3+ KB

# %% [markdown]
# ## Подготовка функций для дальнейшего анализа

# %% [markdown]
# ### Профили пользователей - get_profiles()
# Функция для создания пользовательских профилей, которая принимает на вход таблицы с данными о визитах, покупках и затратах на рекламу, а возвращает сводную таблицу с уникальными id пользователей, датой первого посещения, каналом привлечения, устройством с которого был совершен вход в приложение, регионом, стоимостью привлечения (САС) и флагом payer - совершал пользователь покупки или нет.

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )
    new_users['dt'] = pd.to_datetime(new_users['dt'])
    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['dt'] = ad_costs['dt'].dt.date#astype('datetime64[M]')
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчёта удержания get_retention()
# Функция принимает на вход таблицы профилей пользователей и визитов, а также дату наблюдения, горизонт анализа и параметры разбивки когорт, возвращает таблицу сырых данных (профили, "дожившие" до горизонта анализа), таблицу удержания пользователей, сгруппированную по заданному параметру и таблицу истории удержания.
# По умолчанию функция разбивает пользователей на категорию платящих и нет.
# retention_raw, retention_grouped, retention_history = get_retention(
#     profiles, visits, observation_date, horizon_days, dimensions=dimensions
# )

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта конверсии
# Функция принимает на вход таблицу профилей пользователей, таблицу с информацией о покупках, а также дату наблюдения, горизонт анализа и параметры разбивки когорт, возвращает таблицу сырых данных (профили, "дожившие" до горизонта анализа), таблицу конверсии, сгруппированную по заданным параметрам а также таблицу истории изменения конверсии

# %%
def get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_order = (
        orders.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_order[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция расчета LTV и ROI
# Функция принимает на вход таблицу профилей пользователей, таблицу с информацией о покупках, а также дату наблюдения, горизонт анализа и параметры разбивки когорт, возвращает таблицу сырых данных (профили, "дожившие" до горизонта анализа), таблицу LTV сгруппированную по заданным параметрам, таблицу изменения LTV по датам, таблицу ROI сгруппированную по заданному параметру, а также таблицу изменения ROI по датам.

# %%
def get_ltv(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        orders[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция сглаживания графиков
# Для сглаживания графиков за большой период времени нам потребуется функция скользящего среднего, которая принимает на вход датафрейм и окно сглаживания

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания
# Принимает таблицу удердания пользователей и динамики удержания пользователей, горизонт анализа и окно для сглаживания (по умолчанию - 7 дней)

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии
# Функция принимает таблицу конверсии пользователей, динамики конверсии, значение горизонта анализа и строит графики конверсии и динамики. Окно сглаживания по умолчанию равно 7 дням.

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, legend=False, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI
# Функция принимает для визуализации таблицы LTV и динамики LTV, а также ROI и динамики ROI, горизонт анализа. Окно сглаживания по умолчанию равно 7 дням. Функция строит пять графиков - LTV, динамика LTV, динамика CAC, ROI и динамика ROI.

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# ### Профили пользователей
# С помощью функции get_profiles мы объединили данные о пользовательских сессиях, заказах и затратах на рекламу

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Для каждого уникального ID пользователя функция определяет дату первой сессии в приложении (столбец first_ts). Найдем минимальное и максимальное значение - это будут даты первой и последней сессии в приложении, доступной для анализа

# %%
print('Дата первой сессии в приложении   ', profiles['first_ts'].min())
print('Дата последней сессии в приложении   ', profiles['first_ts'].max())
# Out:
# Дата первой сессии в приложении    2019-05-01 00:00:41
# Дата последней сессии в приложении    2019-10-27 23:59:04

# %% [markdown]
# Определим долю платящих пользователей:

# %%
profiles[profiles['payer'] == True]['payer'].count() / profiles['payer'].count()
# Out:
# 0.05920350914617887

# %% [markdown]
# Всего платят чуть менее 6% пользователей
# <br>
# <br>
# Посмотрим, как распределены пользователи приложения по странам, устройствам и каналам привлечения и долю платящих.
# <br>Для этого зададим функцию, которая примет на вход параметр для группировки и построит сводную таблицу с количеством пользователей и процентом платящих:

# %%
def profiles_by_param(param):
    profiles_grouped = (profiles.groupby(param).agg({'user_id' : 'count', 'payer' : 'mean'})
                    .reset_index().rename(columns={'user_id' : 'num_of_users', 'payer' : '%_of_payers'})
                      .sort_values(by='%_of_payers', ascending=False))
    profiles_grouped['%_of_payers'] = (profiles_grouped['%_of_payers']*100).round(2)
    return profiles_grouped

# %% [markdown]
# Посмотрим на распределение платящих пользователйе по странам:

# %%
profiles_by_param('region')
# Out:
#           region  num_of_users  %_of_payers
# 3  United States        100002         6.90
# 1        Germany         14981         4.11
# 2             UK         17575         3.98
# 0         France         17450         3.80

# %% [markdown]
# Пользователей из США вдвое больше, чем французов, англичан и немцев вместе взятых, последние распределены примерно поровну по 15-17 тысяч. Среди них же и максимальная доля платящих - почти вдвое больше, чем во Франции.

# %% [markdown]
# Посмотрим на распределение платящих пользователйе по устройствам

# %%
profiles_by_param('device')
# Out:
#     device  num_of_users  %_of_payers
# 1      Mac         30042         6.36
# 3   iPhone         54479         6.21
# 0  Android         35032         5.85
# 2       PC         30455         5.05

# %% [markdown]
# Больше всего пользователей на айфонах - чуть больше трети. Меньше всего платят пользователи приложения на ПК.

# %% [markdown]
# Наконец, посмотрим на распределение пользователей по каналам привлечения:

# %%
payers_by_channel = profiles_by_param('channel')
payers_by_channel
# Out:
#                channel  num_of_users  %_of_payers
# 1             FaceBoom         29144        12.20
# 0           AdNonSense          3880        11.34
# 9       lambdaMediaAds          2149        10.47
# 6               TipTop         19561         9.60
# 5       RocketSuperAds          4448         7.91
# 7       WahooNetBanner          8553         5.30
# 8              YRabbit          4312         3.83
# 3         MediaTornado          4364         3.57
# 2              LeapBob          8553         3.06
# 4   OppleCreativeMedia          8605         2.71
# 10             organic         56439         2.06

# %% [markdown]
# Самая платящая группа оказалась и самой многочисленной среди рекламных, но почти половина каналов привлечения дает процент покупателей втрое ниже максимального значения. Органические пользователи ожидаемо платят меньше всех.

# %% [markdown]
# ### Выводы
# Для анализа доступны данные с 01.05.2019 по 27.10.2019.
# <br>Всего платящих пользователей чуть менее 6%.
# <br>Две трети пользователей приложения - из США, остальные примерно поровну распределены между Германией, Великобританией и Францией.
# <br>Доля платящих пользователей в США более чем в полтора раза превышает показатели европейских стран.
# <br>Больше трети пользователей заходят в приложение с iPhone, остальные равномерно распределены межды Mac, Android и PC. Доля платящих выше всего у пользователей продукции Apple, несущественно ниже у пользователей Android и примерно на 20% ниже у пользователей РС.
# <br>Среди платящих пользователей большая неоднородность по каналам привлечения. Самый популярный канал FaceBoom, на долю которого приходится около 20% пользователей, имеет долю платящих пользователей вдвое выше среднего, при этом четыре канала имеют долю платящих вдвое ниже среднего. Более трети всех пользователей приложения нашли его самостоятельно, без рекламы, и доля платящих среди них - чуть более 2%.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# Найдем общую сумму расходов на маркетинг - из таблицы с расходами, простым суммированием столбца costs:

# %%
costs['costs'].sum().round()
# Out:
# 105497.0

# %% [markdown]
# Потрачено 105 тыс. у.е.

# %% [markdown]
# ### Распределение затрат по каналам
# Посмотрим как бюджет маркетинга распределен по каналам привлечения

# %%
costs_by_channel = (costs.groupby('channel').agg({'costs' : 'sum'})
                    .reset_index().sort_values(by='costs', ascending=False))
costs_by_channel
# Out:
#               channel     costs
# 6              TipTop  54751.30
# 1            FaceBoom  32445.60
# 7      WahooNetBanner   5151.00
# 0          AdNonSense   3911.25
# 4  OppleCreativeMedia   2151.25
# 5      RocketSuperAds   1833.00
# 2             LeapBob   1797.60
# 9      lambdaMediaAds   1557.60
# 3        MediaTornado    954.48
# 8             YRabbit    944.22

# %% [markdown]
# Больше половины бюджета потрачено на TipTop, еще треть на FaceBoom, на остальные каналы - на порядок меньше.
# <br>Возможно, новые каналы были задействованы недавно и траты на некоторые еще только-только начались (а на какие-то уже закончились?)
# <br>Чтобы точнее интерпретировать данные посмотрим на распределение трат за доступный нам период, для этого визуализируем размеры трат по каналам во времени.

# %% [markdown]
# ### Динамика расходов
# <br>Посмотрим на динамику трат на рекламу по неделям и месяцам, для этого добавим в датафрейм costs столбцы с номером недели и месяца, просуммируем соответственно траты, а затем визуализируем на одном графике в одном масштабе:

# %%
costs['week'] = costs['dt'].dt.isocalendar().week
costs['month'] = costs['dt'].dt.month

# %%
plt.figure(figsize=(15,5))
ax1 = plt.subplot(1,2,1)
costs.pivot_table(index='week', columns='channel', values='costs', aggfunc='sum').plot(grid=True, ax=ax1)
plt.ylabel('Сумма затрат, у.е.')
plt.title('Динамика недельных затрат на рекламу по каналам')
ax2 = plt.subplot(1,2,2, sharey=ax1)
costs.pivot_table(index='month', columns='channel', values='costs', aggfunc='sum').plot(grid=True, legend=False,  ax=ax2)
plt.title('Динамика месячных затрат на рекламу по каналам')
plt.tight_layout()

# %% [markdown]
# Видно, что все каналы привлечения использовались на протяжении исследуемого периода, и в самом деле траты на FaceBoom и TipTop были на порядок больше остальных, причем похоже, что эффект был виден (либо уверенность в том, что эта реклама обязательно окупится не угасала) и каждый месяц вплоть до октября траты увеличивали. Остальные каналы привлечения использовались стабильно без особых фнансовых вливаний. AdNonSense был слегка урезан к июню и на него стабильно тратилось около 500 у.е. в месяц, чуть больше тратили на WahooNetBanner, как раз начиная с июня - около 1000 у.е. в месяц.

# %% [markdown]
# ### Стоимость привлечения пользователей
# <br>Посмотрим сколько стоило привлечение одного клиента для каждого канала:

# %%
cac_by_channel = (profiles.pivot_table(index='channel', values='acquisition_cost')#по умолчанию будут средние значения
                  .reset_index().sort_values(by='acquisition_cost', ascending=False))
cac_by_channel
# Out:
#                channel  acquisition_cost
# 6               TipTop          2.799003
# 1             FaceBoom          1.113286
# 0           AdNonSense          1.008054
# 9       lambdaMediaAds          0.724802
# 7       WahooNetBanner          0.602245
# 5       RocketSuperAds          0.412095
# 4   OppleCreativeMedia          0.250000
# 8              YRabbit          0.218975
# 3         MediaTornado          0.218717
# 2              LeapBob          0.210172
# 10             organic          0.000000

# %% [markdown]
# Стоимость привлечения одного пользователя по каналу TipTop в 2,5 раза превышает аналогичный показатель для FaceBoom. Половина каналов дает пользователей дешевле в 5-10 раз.

# %% [markdown]
# ### Выводы
# Сведем все полученные данные в одну таблицу для наглядности:

# %%
cac_by_channel[['num_of_users', '%_of_payers']] = payers_by_channel[['num_of_users', '%_of_payers']]
cac_by_channel['ads_cost'] = costs_by_channel['costs']
cac_by_channel
# Out:
#                channel  acquisition_cost  num_of_users  %_of_payers  ads_cost
# 6               TipTop          2.799003         19561         9.60  54751.30
# 1             FaceBoom          1.113286         29144        12.20  32445.60
# 0           AdNonSense          1.008054          3880        11.34   3911.25
# 9       lambdaMediaAds          0.724802          2149        10.47   1557.60
# 7       WahooNetBanner          0.602245          8553         5.30   5151.00
# 5       RocketSuperAds          0.412095          4448         7.91   1833.00
# 4   OppleCreativeMedia          0.250000          8605         2.71   2151.25
# 8              YRabbit          0.218975          4312         3.83    944.22
# 3         MediaTornado          0.218717          4364         3.57    954.48
# 2              LeapBob          0.210172          8553         3.06   1797.60
# 10             organic          0.000000         56439         2.06       NaN

# %% [markdown]
# Траты на рекламу в TipTop с первого взгляда не выглядят оправданными - стоимость пивлечения одного клиента значительно выше, чем по другим каналам, при не самой большой аудитории. Процент платящих пользователей высокий, но не на первом месте с отрывом от остальных.
# <br>FaceBoom производит впечатлениие более удачного решения - САС значительно ниже, а аудитория и процент платящих самые высокие, но окупается ли этот канал еще предстоит выяснить.
# <br>Траты на остальные каналы привлечения вместе взятые значительно меньше первых двух, однако многие из них демонстрируют высокие показатели конверсии при мизерных затратах и САС в 3-5 раз ниже, чем у двух основных. Аудитория этих каналов вместе взятых сравнима с аудиторией TipTop и FaceBoom.
# <br>Доля платящих органических пользователей невелика, но и аудитория примерно 30% от общей. Если средняя конверсия по рекламным каналам - 6% при аудитории 100к пользователей, то 2% конверсии от 56к органических пользователей это больше 15% платящих пользователей.

# %% [markdown]
# ## Оценка окупаемости рекламы
# Для оценки окупаемости рекламы проведм более детальный анализ конкретных показателей.
# <br>В предыдущем разделе было показано, что органический трафик составляет треть общего и дает примерно 15% платящих пользователей, что может существенно исказить показатели окупаемости, поэтому исключим органических пользователей.
# <br>По условию на дворе 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.
# Зададим соответствующие параметры:

# %%
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# ### Общая окупаемость, конверсия и удержание
# Посмотрим на окупаемость рекламы. Визуализируем LTV и ROI с помощью функций, заданных в начале исследования:

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - К концу второй недели ROI составляет лишь 80% - вцелом реклама не окупается
# - В начале мая ситуация была принципиально иной, но с тех пор ROI неуклонно снижался
# - Стоимость привлечения пользователей непрерывно росла с мая по сентябрь и стабилизировалась на максимальных значениях в последние два месяца
# - LTV относительно стабилен на протяжении всего периода, в последний месяц наметился нисходящий тренд, в настоящее время значение минимально с мая месяца

# %% [markdown]
# Рассмотрим конверсию пользователей и динамику её изменения

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия демонстрирует правильный рост, с середины мая не опускаясь ниже 7% и демонстрирует месячные колебания.

# %% [markdown]
# Рассмотрим удержание пользователей и динамику его изменения

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание платящих пользователей выше, чем неплатящих, ожидаемо падает к концу второй недели.
# <br>Динамика была стабильна на протяжении всего периода, демонстрируя недельные колебания, в данный момент находится в нижней точке.

# %% [markdown]
# ### Анализ метрик по параметрам

# %% [markdown]
# #### Удержание
# Посмотрим на удержание пользователей с разбивкой по регионам:

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['region']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# В США удержание ниже, чем в Европейских странах. Учитывая, что две трети пользователей приложения из США, и среди них самаявысокая доля платящих, низкие показатели на американском рынке однозначно влияют на картину вцелом.
# <br>По Германии и Франции график имеет разрывы, видимо из-за вцелом небольшого количества пользователей

# %% [markdown]
# Посмотрим на удержание в разбивке по устройствам:

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['device']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Здесь без сюрпризов. В какие-то моменты были провалы вплоть до нуля, но все проблемы были решены.

# %% [markdown]
# Наконец, сделаем разбивку по каналам привлечения:

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['channel']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Лидер по финансированию - TipTop держится в середняках, а вот два других самых дорогих по САС канала - FaceBoom и AdNoSense стабильно намного ниже - это второй возможный источник проблем.

# %% [markdown]
# Промежуточный вывод - удержание пользователей можно повысить поработав с рынком США и обратив внимание на пришедших из FaceBoom. Возможно, проблем окажется не две а одна, если реклама в FaceBoom ориентирована на американский рынок, что нетрудно выяснить:

# %%
profiles.groupby(['region', 'channel']).agg({'user_id' : 'count'}).reset_index().rename(columns=({'user_id': 'user_count' }))
# Out:
#            region             channel  user_count
# 0          France          AdNonSense        1366
# 1          France             LeapBob        2988
# 2          France  OppleCreativeMedia        2991
# 3          France      WahooNetBanner        2971
# 4          France      lambdaMediaAds         742
# 5         Germany          AdNonSense        1219
# 6         Germany             LeapBob        2519
# 7         Germany  OppleCreativeMedia        2562
# 8         Germany      WahooNetBanner        2579
# 9         Germany      lambdaMediaAds         649
# 10             UK          AdNonSense        1295
# 11             UK             LeapBob        3046
# 12             UK  OppleCreativeMedia        3052
# 13             UK      WahooNetBanner        3003
# 14             UK      lambdaMediaAds         758
# 15  United States            FaceBoom       29144
# 16  United States        MediaTornado        4364
# 17  United States      RocketSuperAds        4448
# ...

# %% [markdown]
# ч.т.д. - два самых затратных рекламных канала направлены только на американский рынок.

# %% [markdown]
# #### Конверсия
# Рассмотрим конверсию в разбивке по регионам, устройствам и каналам привлечения, начнем с региона:

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['region']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия в США вдвое выше, чем в Европе, причем стабильно начиная с июня. В этот момент вливания в европейские каналы привлечения смодерировали, переключившись на рынок США, что, очевидно принесло результаты.
#
# <br>Далее посмотрим на каналы привлечения, эта информация уже была представлена в таблице в конце предыдущего раздела:

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['channel']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Самый дорогой канал TipTop не в лидерах, выделяется канал LambdaMediaAds, нестабильный но с большим потенциалом.
#
# <br>Далее сделаем разбивку по устройствам:

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['device']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Выделяется низкая конверсия пользователей ПК. Возможно, стоит обратить внимание на интерфейс сайта. Заодно проверить и интерфейс приложения на Android, что не так критично, но лишним не будет.

# %% [markdown]
# #### LTV, ROI
# Рассмотрим в разрезе по устройствам, регионам и каналам привлечения другие метрики:

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['device']
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# САС за рассматриваемый период вырос почти вдвое для пользователей Apple и совсем не так значительно для пользователей РС. Последние - единственные, кто приносят прибыль. При этом, их LTV ниже, чем на других устройствах, и, как мы выяснили в разделе 3.1., пользователей РС меньше всего в абсолютном выражении и доля платящих среди них также самая низкая.
# <br>С ростом расходов на рекламу ROI снижался на протяжении всего периода, с сентября реклама не окупается ни на одном из устройств.

# %% [markdown]
# Сделаем разбивку по странам:

# %%
tv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['region']
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Здесь четко выделяются проблемы на американском рынке - при высоком качестве пользователей затраты на рекламу не окупаются только в США, тогда как в Европе в плюс приложение выходит уже через неделю.
# <br>Очевидно в мае компания сделала ставку на агрессивную рекламную кампанию в США, одновременно сократив маркетинговые расходы в Европе, но эта стратегия не окупилась - динамика ROI в США отрицательная, с ростом рекламных трат она быстро опустилась ниже порога окупаемости и продолжает от него отдаляться.

# %% [markdown]
# Далее сделаем разбивку по каналам привлечения:

# %%
tv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['channel']
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Лучшие пользователи пришли от источника LambdaMediaAds, вспоминая финальную таблицу раздела 4 - они были одними из самых дорогих из неосновных каналов привлечения, имели долю платящих более 10%, но их меньше всего в абсолютном выражении - всего 2тыс из 150ти...
# <br>Лидер по тратам на рекламу TipTop также дает очень качественных пользователей с высоким LTV и стабильной динамикой, но затраты на них не окупаются - последнее место в рейтинге ROI.
# <br>Второй, но с конца, канал FaceBoom, в который также вкладывается много денег. Для него, в отличие от TipTop, хотя бы  характерна стабильная стоимость пользователя.
# <br>Не окупается также канал AdNoSense раскручиваемый на европейском рынке.
# <br>Все остальные каналы привлечения, кроме основных, окупаются очень быстро.

# %% [markdown]
# ### Выводы и рекомендации
# 1. Вцелом реклама не окупается - ROI через 14 дней находится на уровне 80%. На это влияет ряд факторов:
# - низкое удержание пользователей на ключевом и самом объемном рынке США
# - низкое удержание пользователей, пришедших по одному из основных рекламных источников - FaceBoom
# По этим причинам реклама не окупается на американском рынке, в то время как в Европе показатели ROI больше единицы.
# - реклама не окупается для пользователей Мас и мобильных устройств
# - низкая конверсия пользователей РС относительно Мас и мобильных устройств
# Пользователи РС тем не менее приносят прибыль несмотря на низкую конверсию
# - реклама в двух основных, самых затратных каналах TipTop и FaceBoom не окупается. Остальные каналы демонстрируют хорошую окупаемость, но на их долю приходится лишь половина пользователей.
# <br>
# 2. Проблемы окупаемости вызваны большими затратами на два основных канала привлечения TipTop и FaceBoom, которые привлекают качественных пользователей с высоким LTV, дают более высокую конверсию но приводят к кратному увеличению САС, но в итоге не окупаются.
# 3. Проблемы могут крыться в ошибочной стратегии направленной на агрессивное привлечение пользователей на американском рынке - большие затраты привлекли большую, но убыточную аудиторию.
# 4. Конверсия пользователей в Европе вдвое ниже, чем в США
#
# <br>**Рекомендации**
# - Динамика на американском рынке тянет компанию вниз. Стоимость привлечения пользователей непрерывно растет, не принося прибыли. Рекомендуется прекратить огромные вливания в TipTop и FaceBoom и проработать рекламные компании на европейском рынке
# - На вцелом прибыльном европейском рынке также есть скрытые проблемы -
#     1. убыточный канал AdNoSense, на который необходимо обратить внимание, в первую очередь на проблему удержания пришедших с него пользователей
#     2. Низкая конверсия пользователей (вдвое ниже относительно США) - скорее всего здесь есть потенциал для роста
# - Конверсия пользователей РС значительно ниже, чем на остальных устройствах, рекомендуется проанализировать интерфейс. Интерфейс Android также имеет потенциал к росту до показателей аналогичного из AppleStore.
# - Из небольших каналов привлечения рекомендуется обратить внимание на LambdaMediaAds, как на самый перспективный.
